# %% [markdown]
# # Research Question, Dataset, and Ethics Check
#
# Use this notebook to document three things for your proposed research project:
#
# 1. Your research question
# 2. The dataset you plan to use
# 3. The ethical aspects you have considered
#
# > Do not load or analyse the data in this notebook. Choose a dataset, provide a reliable reference link, explain why you chose it, and answer the ethics questions using the dataset documentation and any relevant research literature. If a question is not applicable, write N/A and explain why.
#
# ## 1. Research Question
#
# - **Main research question:** Can ocean currents predict future marine microplastic accumulation hotspots.
# - **Why is this question interesting or important?** Microplastics have a detrimental effect on marine life, obtaining information on future potential hotspots of microplastics could help in ifentifying locations at potential risk of future exposure.
# - **Who might use or care about the answer?** Environmental scientists, environmental activists, coastal communities
# - **Possible sub-questions:** Where are the major existing marine microplastic hotspots?
#
# ## 2. Dataset Reference
#
# - **Dataset name:** Marine Microplastics, Exploring Temporal Trends in Marine Microplastic Density
# - **Source link:** https://www.kaggle.com/datasets/william2020/marine-microplastics
# - **Date accessed:** [2026-09-17]
# - **Who published or collected it?** William Zebrowski
# - **Why did you choose this dataset?** This database contains information on microplastic concentration, region, date of collection and latitude and longitude of sample collected. It provides knowledge on the microplastic samples locations and quantity.
# - **Evidence or notes:** [Add links, citations, or brief notes that support your choice.]

# %% [markdown]
# ## Research Questions and Answers
#
# For every answer, distinguish between **known evidence**, **reasonable interpretation**, and **unknown information to investigate**.
#
# ### 1. Where did the data come from?
#
# **Answer:** The data came from a database publicly available on the kaggle website under the the title of 'Marine Microplastics, Exploring Temporal Trends in Marine Microplastic Density'. It was collected by William Zebrowski an AI research engineer, who collected and organised the concentration and location of approx. 20,000 marine microplastic samples collected from a wde range of sources including Adventure Scientist, Sea Education Association, Scripps Institution of Oceanography-University of California San Diego (please see full list of DOI below). The dataset was accessed 17/09/2026.
#
# DOI:
# http://dx.doi.org/10.1016/j.marpolbul.2016.12.025
# http://dx.doi.org/10.1016/j.scitotenv.2022.155958
# http://dx.doi.org/10.12681/mms.24899
# https://doi.org/10.1007/s11356-015-4453-3
# https://doi.org/10.1007/s11852-021-00846-z
# https://doi.org/10.1016/j.envint.2020.105494
# https://doi.org/10.1016/j.envpol.2017.09.058
# https://doi.org/10.1016/j.envpol.2018.02.062
# https://doi.org/10.1016/j.envpol.2022.120702
# https://doi.org/10.1016/j.marpolbul.2012.12.021
# https://doi.org/10.1016/j.marpolbul.2016.12.052
# https://doi.org/10.1016/j.marpolbul.2018.03.011
# https://doi.org/10.1016/j.marpolbul.2019.01.053
# https://doi.org/10.1016/j.marpolbul.2019.04.023
# https://doi.org/10.1016/j.marpolbul.2019.07.068
# https://doi.org/10.1016/j.marpolbul.2019.110572
# https://doi.org/10.1016/j.marpolbul.2019.110757
# https://doi.org/10.1016/j.marpolbul.2019.110794
# https://doi.org/10.1016/j.marpolbul.2020.111092
# https://doi.org/10.1016/j.marpolbul.2020.111225
# https://doi.org/10.1016/j.marpolbul.2020.111515
# https://doi.org/10.1016/j.marpolbul.2021.112210
# https://doi.org/10.1016/j.resconrec.2019.104633
# https://doi.org/10.1016/j.rsma.2022.102423
# https://doi.org/10.1016/j.scitotenv.2019.01.319
# https://doi.org/10.1016/j.scitotenv.2022.154036
# https://doi.org/10.1016/j.scitotenv.2022.156259
# https://doi.org/10.1021/acs.est.2c05926
# https://doi.org/10.1021/es4053076
# https://doi.org/10.1038/s41598-020-64465-8
# https://doi.org/10.1038/s41598-021-85939-3
# https://doi.org/10.1038/s41598-022-17742-7
# https://doi.org/10.1038/s41598-023-36228-8
# https://doi.org/10.1038/s43247-021-00091-0
# https://doi.org/10.1038/srep37551
# https://doi.org/10.1088/1748-9326/abbb4f
# https://doi.org/10.1088/1748-9326/ac5df1
# https://doi.org/10.1126/science.1192321
# https://doi.org/10.1371/journal.pone.0080020
# https://doi.org/10.1371/journal.pone.0111913
# https://doi.org/10.1371/journal.pone.0161581
# https://doi.org/10.1371/journal.pone.0243203
# https://doi.org/10.3389/fenvs.2020.582217
# https://doi.org/10.3389/fenvs.2022.998513
# https://doi.org/10.3389/fmars.2021.626026
# https://doi.org/10.3389/fmars.2021.699000
# https://doi.org/10.3389/fmars.2022.784937
#
# [Describe the original source, collection method, owner, URL/DOI, and date accessed. Cite evidence where possible.]
#
# ### 2. Why was it originally collected?
#
# **Answer:** This data was collected for the purposes of examining microplastic density changes across regions, identifying patterns of density changes across a monthly and seasonal basis, evaluating efficiency of different sampling methods in detection of microplastics, visualising geographical distribution of marine microplastics and assessing the contribution of different organisations towards the analysis of marine microplastics.
#
# As this dataset was publically published on the Kaggle website we can reasonably infer that another purpose of the collection of this data was to allow it to be easily reached by the public for acadmic or professional purposes.
#
# [State the original purpose. If the current project uses it for a different purpose, explain that change and whether it is ethically justified.]
#
# ### 3. Who is represented?
#
# **Answer:** There are two groups represented by this data, marine microplastics and the organisations who collected the samples. The microplastic samples were collected from a wide range of locations including the Arctic Ocean, Atlantic Ocean, Indian Ocean and Pacific Ocean, including all their sub regions.
#
# The organisations who collected this data include but are not limited to universities, foundations, research centres etc. Spanning across a wide range of countries .
#
# [Describe the population, groups, locations, time period, and sampling frame represented by the data.]
#
# ### 4. Who might be missing?
#
# The data in our dataset is limited to what was able to be collected by the owner, therefore, there may be other organisations who have collected micrplastic samples which may be not represented in the data.
#
# **Answer:** [Identify groups excluded by the sampling method, missing responses, access barriers, non-response, or incomplete records.]
#
# ### 5. What personal or sensitive information does it contain, explicitly or implicitly?
#
# This dataset does not directly contain any sensitive information particularly regarding the organisations responsible for collecting this data, containing only microplastic concentration and location. Any of the data collected was sourced from publicly available sources supported by reference.
#
# **Answer:** [List direct identifiers and sensitive fields. Also identify combinations of fields that could identify people or act as proxies for sensitive attributes.]
#
# ### 6. What could your analysis reveal that was not obvious in the original data?
#
# Our analysis could potentially reveal patterns in locations of marine microplastic locations, correlating microplastic population to other factors such as surrounding areas, specific oceans and distance to coastal areas. Our analysis could also reveal the degree to which different organisations indirectly contributed to the collected data, given the number of samples attributed to them.
#
# **Answer:** [Describe possible inferences, correlations, predictions, re-identification risks, or conclusions about individuals or groups.]
#
# ### 7. Who could benefit from your findings?
#
# The findings could benefit marine scientists, environmental organisations, communities in the analysed areas. Scientists could use these findings to better understand and predict microplastic accumulation, environmental organisations may find this helpful in locating marine populations at risk and communities may find this information useful in prepraring for the potentiality that they could come to risk.
#
# **Answer:** [Identify the people, communities, organisations, or decision-makers who could benefit, and explain how.]
#
# ### 8. Who could be harmed or misrepresented?
#
# This dataset does not delve into private matters of any affected groups. The only information included on the organisations responsible for collecting the data is limited to the sample that was collected, a reference to where the owner of the dataset collected the data, and the name of the organisation. However, the data is limited to what the owner was able to collect, therefore, there may be data of microplastic sample locations collected by other organisations that is not included in this dataset.
#
# **Answer:** [Identify people or groups who could experience privacy loss, discrimination, stigma, exclusion, incorrect decisions, or misleading representation.]
